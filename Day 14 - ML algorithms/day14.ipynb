# %% [markdown]
# Choosing Algorithm
#
# - Nature of the problem
# - Nature of Algorithms
# - Perfromance Comparison

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Linear Regression
# - Rgeression Problem
#
# Logistic Regression
# - Classification Problem
# - Threshhold Value
# - SIgmoid function
#
# Support Vecor Machines
# - Classification and regressssion
# - Linear and Non Linear Problems
# - Hyperplane
# - Kernal
#
# Decsion Tree
# - Callsif regression
# - Calssif Preffreed
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Ensamble Algorithms
# - Bagging - Random Forest
# - Boosting - AdaBoost XGBoost
#
# Random Forest
# - Classif and regression
# - Multiple Parellel models then vote and select most voted
#
# AdaBoost
# - Sequential models
#     - model 1 runs
#     - get weekness
#     - more weight is given to weakness
#
# XGBoost
# - Decison tree based
# - handles null values and extreme values
# - Minimizes Error Using Gradient descent
